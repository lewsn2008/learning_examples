# %% [markdown]
# Refer to：https://github.com/ywpkwon/siamese_tf_mnist

# %%
# %matplotlib inline
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
class SiameseNN:
    # Create model
    def __init__(self):
        self.x1 = tf.placeholder(tf.float32, [None, 784])
        self.x2 = tf.placeholder(tf.float32, [None, 784])

        with tf.variable_scope("siamese") as scope:
            self.o1 = self.network(self.x1)
            scope.reuse_variables()
            self.o2 = self.network(self.x2)

        self.y_ = tf.placeholder(tf.float32, [None])
        self.loss = self.loss_with_spring()

    def network(self, x): 
        fc1 = self.fc_layer(x, 1024, "fc1")
        ac1 = tf.nn.relu(fc1)
        fc2 = self.fc_layer(ac1, 1024, "fc2")
        ac2 = tf.nn.relu(fc2)
        fc3 = self.fc_layer(ac2, 2, "fc3")
        return fc3 
 
    def fc_layer(self, input_, size, name):
        input_dim = input_.get_shape()[1]
        initer = tf.truncated_normal_initializer(stddev=0.01)
        W = tf.get_variable(name + '_W', dtype=tf.float32, shape=[input_dim, size], initializer=initer)
        b = tf.get_variable(name + '_b', dtype=tf.float32, initializer=tf.constant(0.01, shape=[size], dtype=tf.float32))
        fc = tf.nn.bias_add(tf.matmul(input_, W), b)
        return fc

    def loss_with_spring(self):                                                                                                                     
        margin = 5.0
        labels_t = self.y_
        labels_f = tf.subtract(1.0, self.y_, name="1-yi")          # labels_ = !labels;
        eucd2 = tf.pow(tf.subtract(self.o1, self.o2), 2)
        eucd2 = tf.reduce_sum(eucd2, 1)
        eucd = tf.sqrt(eucd2+1e-6, name="eucd")
        C = tf.constant(margin, name="C")
        # yi*||CNN(p1i)-CNN(p2i)||^2 + (1-yi)*max(0, C-||CNN(p1i)-CNN(p2i)||^2)
        pos = tf.multiply(labels_t, eucd2, name="yi_x_eucd2")
        # neg = tf.multiply(labels_f, tf.subtract(0.0,eucd2), name="yi_x_eucd2")
        # neg = tf.multiply(labels_f, tf.maximum(0.0, tf.subtract(C,eucd2)), name="Nyi_x_C-eucd_xx_2")
        neg = tf.multiply(labels_f, tf.pow(tf.maximum(tf.subtract(C, eucd), 0), 2), name="Nyi_x_C-eucd_xx_2")
        losses = tf.add(pos, neg, name="losses")
        loss = tf.reduce_mean(losses, name="loss")
        return loss

# prepare data and tf.session
mnist = input_data.read_data_sets('MNIST_data', one_hot=False)
#sess = tf.InteractiveSession()

# setup siamese network
siamese = SiameseNN()
train_step = tf.train.GradientDescentOptimizer(0.01).minimize(siamese.loss)
saver = tf.train.Saver()
init = tf.global_variables_initializer()                                                                                                     

# if you just want to load a previously trainmodel?
new = True

# start training
embed = None
with tf.Session() as sess:
    sess.run(init)
    if new:
        for step in range(100000):
            batch_x1, batch_y1 = mnist.train.next_batch(128)
            batch_x2, batch_y2 = mnist.train.next_batch(128)
            batch_y = (batch_y1 == batch_y2).astype('float')

            _, loss_v = sess.run([train_step, siamese.loss],
                                 feed_dict={siamese.x1: batch_x1,
                                            siamese.x2: batch_x2,
                                            siamese.y_: batch_y})

            if np.isnan(loss_v):
                print('Model diverged with loss = NaN')
                quit()                                                                                                                                  

            if step % 1000 == 0:
                print ('step %d: loss %.3f' % (step, loss_v))

            if step % 10000 == 0 and step > 0:
                saver.save(sess, 'checkpoints/model.ckpt')
                embed = siamese.o1.eval({siamese.x1: mnist.test.images})
                embed.tofile('temp/embed.txt')
    else:
        saver.restore(sess, 'checkpoints/model.ckpt')
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# step 0: loss 22.024
# step 1000: loss 1.873
# step 2000: loss 0.991
# step 3000: loss 0.864
# step 4000: loss 1.154
# step 5000: loss 1.027
# step 6000: loss 0.316
# step 7000: loss 0.618
# step 8000: loss 0.164
# step 9000: loss 0.188
# step 10000: loss 0.510
# step 11000: loss 0.323
# step 12000: loss 0.306
# step 13000: loss 1.332
# step 14000: loss 0.119
# step 15000: loss 0.109
# step 16000: loss 0.298
# step 17000: loss 0.175
# step 18000: loss 0.136
# step 19000: loss 0.156
# step 20000: loss 0.185
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-cd1071eb6fe8> in <module>()
#      72                                  feed_dict={siamese.x1: batch_x1,
# ...

# %%
x_test = mnist.test.images.reshape([-1, 28, 28])
feat = embed
ax_min = np.min(embed,0)
ax_max = np.max(embed,0)
ax_dist_sq = np.sum((ax_max-ax_min)**2)                                                               

plt.figure(figsize=(16, 12))
ax = plt.subplot(111)                                                                                 
shown_images = np.array([[1., 1.]])                                                                   
for i in range(feat.shape[0]):
    dist = np.sum((feat[i] - shown_images)**2, 1)
    if np.min(dist) < 3e-4*ax_dist_sq:   # don't show points that are too close                       
        continue                                                                                      
    shown_images = np.r_[shown_images, [feat[i]]]
    imagebox = offsetbox.AnnotationBbox(
        offsetbox.OffsetImage(x_test[i], zoom=0.6, cmap=plt.cm.gray_r),
        xy=feat[i], frameon=False
    )                                                                                                                                                                                                         
    ax.add_artist(imagebox)

plt.axis([ax_min[0], ax_max[0], ax_min[1], ax_max[1]])                                                
# plt.xticks([]), plt.yticks([])                                                                      
plt.title('Embedding from the last layer of the network')                                             
plt.show()
